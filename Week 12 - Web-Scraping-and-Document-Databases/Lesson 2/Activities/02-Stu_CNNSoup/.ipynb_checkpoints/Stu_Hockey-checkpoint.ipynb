# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('li', class_='mixed-feed__item--article')

# Loop through results to retrieve article title, header, and timestamp of article
for result in results:
    title = result.find('h4', class_='mixed-feed__header').text

    lede = result.find('h5', class_='mixed-feed__subheader').text

    # The time and date of article publication
    date = result.find('time')['datetime']
    # Slice the datetime string for the date
    article_date = date[:10]
    # Slice the datetime string for the time
    time = date[11:16]
    # Determine whether article was published in AM or PM
    if (int(time[:2]) >= 13):
        meridiem = 'pm'
    else:
        meridiem = 'am'

    # Concatenate time string
    time = time + meridiem
    print('-----------------')
    print(title)
    print(lede)
    print(article_date)
    print(time)

    # Dictionary to be inserted into MongoDB
    post = {
        'title': title,
        'lede': lede,
        'date': article_date,
        'time published': time
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Thornton expected to return with Sharks, Meier says
# 40-year-old forward is unrestricted free agent
# 2019-08-15
# 13:10pm
# -----------------
# Aho thankful for contract with Hurricanes after Canadiens' offer sheet
# Center says process helped ensure he'd start training camp on time
# 2019-08-15
# 13:50pm
# -----------------
# Marner, Maple Leafs will work out contract, Nylander says
# Forward went through same situation last offseason as restricted free agent, says 'it just takes time'
# 2019-08-15
# 13:51pm
# -----------------
# Hedman says 'body is great' ahead of training camp with Lightning
# Defenseman, who was finalist for Norris Trophy, missed 14 games last season because of injuries
# 2019-08-15
# 12:31am
# -----------------
# Top prospects for Minnesota Wild
# Sturm expected to vie for roster spot; Boldy set to attend Boston College
# 2019-08-15
# 00:00am
# -----------------
# Marleau, Thornton skate at Sharks practice site
# Unrestricted free agent forwards each hoping to play 22nd NHL season
# 2019-08-14
# 12:55am
# -----------------
# Mailbag: Blues' title defense, Hall's chances of re-signing with Devils
# NHL.com's Dan Rosen answers weekly questions
# 2019-08-14
# 00:00am
# -----------------
# Minnesota Wild fantasy preview for 2019-20
# Dubnyk, Dumba remain valuable options; Zuccarello can boost top six, power play
# 2019-08-15
# 00:00am
# -----------------
# Fiala waiting on Wild GM search to re-start contract negotiations
# Restricted free agent forward had been in discussions with Fenton prior to his firing
# 2019-08-15
# 11:50am
# -----------------
# Sundqvist takes Cup on helicopter ride in Sweden
# Blues forward enjoyed day with trophy in Skelleftea
# 2019-08-14
# 21:02pm
# -----------------
# NHL Free Agent Tracker
# Complete list of signings by team, available players
# 2019-08-13
# 15:20pm
# -----------------
# Blues GM Armstrong records hole-in-one at Nova Scotia golf course
# Architect of Cup championship team aced par-3 16th hole at Cabot Cliffs
# 2019-08-15
# 19:17pm
# -----------------
# NHL hopes to soon announce return to China for preseason games
# Deputy Commissioner praises Ovechkin for role as League ambassador to country
# 2019-08-15
# 14:00pm
# -----------------
# Werenski intends to sign with Blue Jackets before training camp: report
# Defenseman, who is restricted free agent, had 44 points last season
# 2019-08-14
# 12:22am
# -----------------
# Metropolitan Division fantasy preview for 2019-20
# Flyers lead group with 11 in top 250; Lundqvist, Rangers have renewed upside after Panarin, Kakko, Trouba additions
# 2019-08-14
# 13:00pm
# -----------------
# Minnesota Wild key statistics
# Donato has strong SAT rating; Dubnyk among best in wins
# 2019-08-15
# 00:00am
# -----------------
# 2019-20 NHL Trade Tracker
# Official deals since June 14
# 2019-08-14
# 14:30pm
# -----------------
# Three questions facing Minnesota Wild
# GM search, play of Staal, Zucker among areas of focus
# 2019-08-15
# 00:00am
# -----------------
# Inside look at Los Angeles Kings
# New coach McLellan tasked with helping improve offense, spark return to playoffs
# 2019-08-14
# 00:00am
# -----------------
# SJ Sharkie escorts students in Gilroy to school on first day
# Mascot friendly face in California town that was site of recent mass shooting
# 2019-08-14
# 18:19pm
# -----------------
# Top prospects for Los Angeles Kings
# Turcotte ready to skate at Wisconsin; Vilardi on track to play in NHL if healthy
# 2019-08-14
# 01:00am
# -----------------
# Los Angeles Kings fantasy preview for 2019-20
# Kopitar among bounce-back candidates; Toffoli can benefit from new coach McLellan in contract year
# 2019-08-14
# 00:00am
# -----------------
# Los Angeles Kings key statistics
# Power-play needs addressed; Campbell's save percentage among best
# 2019-08-14
# 00:00am
# -----------------
# Fantasy team previews for 2019-20 season
# NHL.com identifies relevant players, storylines from each roster around League
# 2019-08-15
# 00:00am
# -----------------
# NHL Fantasy on Ice podcast available now
# Season preview episodes: Mock draft 1.0, top rookies, bounce-back candidates, coaching changes
# 2019-08-06
# 18:04pm
# -----------------
# NHL introduces children of color to hockey at Martha's Vineyard festival
# Kids try shooting, stickhandling, meet O'Ree at annual gathering of black families
# 2019-08-13
# 19:16pm
# -----------------
# Fantasy hockey top 250 rankings for 2019-20
# Panthers have Bobrovsky, Barkov among 20 best; rookies Kakko, Makar join Hughes in first 100; Gusev, Neal added to list
# 2019-08-01
# 13:00pm
# -----------------
# Laine, Marner, Rantanen among top unsigned restricted free agents
# Connor, Point, Tkachuk, others waiting for contract or offer sheet
# 2019-08-14
# 21:08pm
# -----------------
# Williams, Gardiner, Marleau, Thornton remain unrestricted free agents
# Hutton, Phaneuf, Ward among those available
# 2019-08-10
# 19:40pm
# -----------------
# 2019 NHL Draft first-round pick signings tracker
# Status of 31 players chosen in opening round in Vancouver
# 2019-08-06
# 13:45pm

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5d55f6686fcf8b8106752ad7'), 'title': 'Thornton expected to return with Sharks, Meier says', 'lede': '40-year-old forward is unrestricted free agent', 'date': '2019-08-15', 'time published': '13:10pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ad8'), 'title': "Aho thankful for contract with Hurricanes after Canadiens' offer sheet", 'lede': "Center says process helped ensure he'd start training camp on time", 'date': '2019-08-15', 'time published': '13:50pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ad9'), 'title': 'Marner, Maple Leafs will work out contract, Nylander says', 'lede': "Forward went through same situation last offseason as restricted free agent, says 'it just takes time'", 'date': '2019-08-15', 'time published': '13:51pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ada'), 'title': "Hedman says 'body is great' ahead of training camp with Lightning", 'lede': 'Defenseman, who was finalist for Norris Trophy, missed 14 games last season because of injuries', 'date': '2019-08-15', 'time published': '12:31am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752adb'), 'title': 'Top prospects for Minnesota Wild', 'lede': 'Sturm expected to vie for roster spot; Boldy set to attend Boston College', 'date': '2019-08-15', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752adc'), 'title': 'Marleau, Thornton skate at Sharks practice site', 'lede': 'Unrestricted free agent forwards each hoping to play 22nd NHL season', 'date': '2019-08-14', 'time published': '12:55am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752add'), 'title': "Mailbag: Blues' title defense, Hall's chances of re-signing with Devils", 'lede': "NHL.com's Dan Rosen answers weekly questions", 'date': '2019-08-14', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ade'), 'title': 'Minnesota Wild fantasy preview for 2019-20', 'lede': 'Dubnyk, Dumba remain valuable options; Zuccarello can boost top six, power play', 'date': '2019-08-15', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752adf'), 'title': 'Fiala waiting on Wild GM search to re-start contract negotiations', 'lede': 'Restricted free agent forward had been in discussions with Fenton prior to his firing', 'date': '2019-08-15', 'time published': '11:50am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae0'), 'title': 'Sundqvist takes Cup on helicopter ride in Sweden', 'lede': 'Blues forward enjoyed day with trophy in Skelleftea', 'date': '2019-08-14', 'time published': '21:02pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae1'), 'title': 'NHL Free Agent Tracker', 'lede': 'Complete list of signings by team, available players', 'date': '2019-08-13', 'time published': '15:20pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae2'), 'title': 'Blues GM Armstrong records hole-in-one at Nova Scotia golf course', 'lede': 'Architect of Cup championship team aced par-3 16th hole at Cabot Cliffs', 'date': '2019-08-15', 'time published': '19:17pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae3'), 'title': 'NHL hopes to soon announce return to China for preseason games', 'lede': 'Deputy Commissioner praises Ovechkin for role as League ambassador to country', 'date': '2019-08-15', 'time published': '14:00pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae4'), 'title': 'Werenski intends to sign with Blue Jackets before training camp: report', 'lede': 'Defenseman, who is restricted free agent, had 44 points last season', 'date': '2019-08-14', 'time published': '12:22am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae5'), 'title': 'Metropolitan Division fantasy preview for 2019-20', 'lede': 'Flyers lead group with 11 in top 250; Lundqvist, Rangers have renewed upside after Panarin, Kakko, Trouba additions', 'date': '2019-08-14', 'time published': '13:00pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae6'), 'title': 'Minnesota Wild key statistics', 'lede': 'Donato has strong SAT rating; Dubnyk among best in wins', 'date': '2019-08-15', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae7'), 'title': '2019-20 NHL Trade Tracker', 'lede': 'Official deals since June 14', 'date': '2019-08-14', 'time published': '14:30pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae8'), 'title': 'Three questions facing Minnesota Wild', 'lede': 'GM search, play of Staal, Zucker among areas of focus', 'date': '2019-08-15', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752ae9'), 'title': 'Inside look at Los Angeles Kings', 'lede': 'New coach McLellan tasked with helping improve offense, spark return to playoffs', 'date': '2019-08-14', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752aea'), 'title': 'SJ Sharkie escorts students in Gilroy to school on first day', 'lede': 'Mascot friendly face in California town that was site of recent mass shooting', 'date': '2019-08-14', 'time published': '18:19pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752aeb'), 'title': 'Top prospects for Los Angeles Kings', 'lede': 'Turcotte ready to skate at Wisconsin; Vilardi on track to play in NHL if healthy', 'date': '2019-08-14', 'time published': '01:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752aec'), 'title': 'Los Angeles Kings fantasy preview for 2019-20', 'lede': 'Kopitar among bounce-back candidates; Toffoli can benefit from new coach McLellan in contract year', 'date': '2019-08-14', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752aed'), 'title': 'Los Angeles Kings key statistics', 'lede': "Power-play needs addressed; Campbell's save percentage among best", 'date': '2019-08-14', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752aee'), 'title': 'Fantasy team previews for 2019-20 season', 'lede': 'NHL.com identifies relevant players, storylines from each roster around League', 'date': '2019-08-15', 'time published': '00:00am'}
# {'_id': ObjectId('5d55f6686fcf8b8106752aef'), 'title': 'NHL Fantasy on Ice podcast available now', 'lede': 'Season preview episodes: Mock draft 1.0, top rookies, bounce-back candidates, coaching changes', 'date': '2019-08-06', 'time published': '18:04pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752af0'), 'title': "NHL introduces children of color to hockey at Martha's Vineyard festival", 'lede': "Kids try shooting, stickhandling, meet O'Ree at annual gathering of black families", 'date': '2019-08-13', 'time published': '19:16pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752af1'), 'title': 'Fantasy hockey top 250 rankings for 2019-20', 'lede': 'Panthers have Bobrovsky, Barkov among 20 best; rookies Kakko, Makar join Hughes in first 100; Gusev, Neal added to list', 'date': '2019-08-01', 'time published': '13:00pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752af2'), 'title': 'Laine, Marner, Rantanen among top unsigned restricted free agents', 'lede': 'Connor, Point, Tkachuk, others waiting for contract or offer sheet', 'date': '2019-08-14', 'time published': '21:08pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752af3'), 'title': 'Williams, Gardiner, Marleau, Thornton remain unrestricted free agents', 'lede': 'Hutton, Phaneuf, Ward among those available', 'date': '2019-08-10', 'time published': '19:40pm'}
# {'_id': ObjectId('5d55f6686fcf8b8106752af4'), 'title': '2019 NHL Draft first-round pick signings tracker', 'lede': 'Status of 31 players chosen in opening round in Vancouver', 'date': '2019-08-06', 'time published': '13:45pm'}
