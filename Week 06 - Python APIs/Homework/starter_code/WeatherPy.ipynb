# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
# Dependencies
import csv
import matplotlib.pyplot as plt
import openweathermapy as ow
import pandas as pd
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['punta arenas',
#  'khatanga',
#  'longyearbyen',
#  'nizhneyansk',
#  'luderitz',
#  'olafsvik',
#  'nelson bay',
#  'tura',
#  'souillac',
#  'el sauzal',
#  'jamestown',
#  'barrow',
#  'karratha',
#  'baiyin',
#  'hermanus',
#  'sumbe',
#  'northam',
#  'vaini',
#  'yellowknife',
#  'chapais',
#  'tumannyy',
#  'te anau',
#  'vao',
#  'lagoa',
#  'pleasanton',
#  'airai',
#  'rikitea',
#  'yuksekova',
#  'illoqqortoormiut',
#  'kavaratti',
#  'hobart',
#  'thompson',
#  'busselton',
#  'hilo',
#  'ushuaia',
#  'sapucaia',
#  'nanortalik',
#  'taolanaro',
#  'avarua',
#  'opuwo',
#  'coihaique',
#  'bandarbeyla',
#  'deputatskiy',
#  'nanchang',
#  'arraial do cabo',
#  'esperance',
#  'townsville',
#  'samarai',
#  'kangaatsiaq',
#  'kapaa',
#  'fairbanks',
#  'talnakh',
#  'diamantino',
#  'provideniya',
#  'camana',
#  'atuona',
#  'tuktoyaktuk',
#  'bannu',
#  'albany',
#  'san antonio',
#  'itirapina',
#  'deniliquin',
#  'itoman',
#  'puerto ayacucho',
#  'ostrovnoy',
#  'cape town',
#  'ryotsu',
#  'griffith',
#  'salinopolis',
#  'imeni poliny osipenko',
#  'fortuna',
#  'puerto ayora',
#  'hualmay',
#  'goderich',
#  'trenggalek',
#  'inuvik',
#  'vila franca do campo',
#  'butaritari',
#  'omboue',
#  'kuna',
#  'birjand',
#  'tigre',
#  'vicente guerrero',
#  'san nicolas',
#  'severo-kurilsk',
#  'ancud',
#  'damietta',
#  'bluff',
#  'yamada',
#  'kachikau',
#  'lebu',
#  'chuy',
#  'palabuhanratu',
#  'aklavik',
#  'taoudenni',
#  'hope',
#  'san lorenzo',
#  'pevek',
#  'paamiut',
#  'geraldton',
#  'wuan',
#  'vaitupu',
#  'kenai',
#  'fukue',
#  'carutapera',
#  'kasongo-lunda',
#  'hervey bay',
#  'tasiilaq',
#  'upernavik',
#  'aflu',
#  'bredasdorp',
#  'chokurdakh',
#  'severodvinsk',
#  'bambous virieux',
#  'saint george',
#  'nome',
#  'monrovia',
#  'belushya guba',
#  'bintulu',
#  'clyde river',
#  'cherskiy',
#  'narsaq',
#  'kutum',
#  'verkhniye tatyshly',
#  'mataura',
#  'port alfred',
#  'touros',
#  'mareeba',
#  'sept-iles',
#  'huanren',
#  'tweed',
#  'fomboni',
#  'bay roberts',
#  'lorengau',
#  'wanning',
#  'cordoba',
#  'leisure city',
#  'entre rios',
#  'east london',
#  'krasnoselkup',
#  'miri',
#  'hithadhoo',
#  'susanville',
#  'agar',
#  'san cristobal',
#  'new norfolk',
#  'sedelnikovo',
#  'flinders',
#  'kinshasa',
#  'puerto del rosario',
#  'sembakung',
#  'kavieng',
#  'dingle',
#  'onega',
#  'kaeo',
#  'honiara',
#  'mandapam',
#  'katsuura',
#  'launceston',
#  'walvis bay',
#  'vila velha',
#  'lompoc',
#  'faanui',
#  'dikson',
#  'lazaro cardenas',
#  'phan thiet',
#  'pangody',
#  'vardo',
#  'kruisfontein',
#  'tiksi',
#  'saint-philippe',
#  'sudzha',
#  'coquimbo',
#  'norman wells',
#  'dukat',
#  'curuca',
#  'shenzhen',
#  'carnarvon',
#  'guerrero negro',
#  'leningradskiy',
#  'whitecourt',
#  'kijang',
#  'benjamin hill',
#  'urusha',
#  'pisco',
#  'vanavara',
#  'port hardy',
#  'ozark',
#  'ohara',
#  'laguna',
#  'leh',
#  'husavik',
#  'beberibe',
#  'banda aceh',
#  'lakes entrance',
#  'georgetown',
#  'ahipara',
#  'bilibino',
#  'castro',
#  'mar del plata',
#  'ngunguru',
#  'daru',
#  'umzimvubu',
#  'hasaki',
#  'guna',
#  'turhal',
#  'matam',
#  'sentyabrskiy',
#  'portland',
#  'port elizabeth',
#  'jiwani',
#  'bloemfontein',
#  'merauke',
#  'acajutla',
#  'salto',
#  'la ronge',
#  'kodiak',
#  'cayenne',
#  'amderma',
#  'caravelas',
#  'grand gaube',
#  'pangnirtung',
#  'corinto',
#  'kumluca',
#  'sola',
#  'bethel',
#  'sur',
#  'tevaitoa',
#  'berdyuzhye',
#  'atar',
#  'saldanha',
#  'nabire',
#  'kodinar',
#  'severo-yeniseyskiy',
#  'kahului',
#  'lagunas',
#  'cabo san lucas',
#  'rakitnoye',
#  'nikolskoye',
#  'qiryat yam',
#  'sladkovo',
#  'pindiga',
#  'tongsa',
#  'grindavik',
#  'komsomolskiy',
#  'mitsamiouli',
#  'istisu',
#  'mananjary',
#  'aktau',
#  'cidreira',
#  'linkoping',
#  'waingapu',
#  'tapaua',
#  'nouakchott',
#  'toamasina',
#  'kaitangata',
#  'kupang',
#  'owando',
#  'acari',
#  'baker city',
#  'kedougou',
#  'yumen',
#  'stephenville',
#  'taltal',
#  'sinnamary',
#  'sabha',
#  'pilar',
#  'alofi',
#  'san-pedro',
#  'vrangel',
#  'satitoa',
#  'lavrentiya',
#  'aksay',
#  'sao joao da barra',
#  'polunochnoye',
#  'labutta',
#  'qaqortoq',
#  'saleaula',
#  'luga',
#  'lavumisa',
#  'saint-pierre',
#  'victoria',
#  'birao',
#  'isangel',
#  'boden',
#  'san patricio',
#  'hvide sande',
#  'sinegorye',
#  'comodoro rivadavia',
#  'karak',
#  'beringovskiy',
#  'honningsvag',
#  'solovetskiy',
#  'simbahan',
#  'ust-kut',
#  'ribeira grande',
#  'kuantan',
#  'foumban',
#  'synya',
#  'evensk',
#  'hambantota',
#  'mys shmidta',
#  'sao filipe',
#  'kokologo',
#  'coswig',
#  'ouesso',
#  'stavern',
#  'podgornoye',
#  'asau',
#  'meulaboh',
#  'faya',
#  'wenatchee',
#  'gamba',
#  'grande prairie',
#  'alexandria',
#  'sao lourenco do sul',
#  'hun',
#  'broome',
#  'avera',
#  'warrnambool',
#  'willowmore',
#  'tuatapere',
#  'mount gambier',
#  'buchanan',
#  'saskylakh',
#  'skalistyy',
#  'filingue',
#  'suntar',
#  'saint-georges',
#  'visby',
#  'yerbogachen',
#  'darhan',
#  'solnechnyy',
#  'ivanovka',
#  'rawson',
#  'hay river',
#  'dali',
#  'riyadh',
#  'karaul',
#  'cairns',
#  'poum',
#  'namibe',
#  'tyrma',
#  'kalamare',
#  'paramonga',
#  'ziyang',
#  'yulara',
#  'kaseda',
#  'tomigusuku',
#  'batemans bay',
#  'mvuma',
#  'mokhsogollokh',
#  'ladario',
#  'devils lake',
#  'moron',
#  'yeniseysk',
#  'barentsburg',
#  'akureyri',
#  'manglaur',
#  'methven',
#  'attawapiskat',
#  'mayo',
#  'haibowan',
#  'huilong',
#  'nuuk',
#  'chandbali',
#  'camacha',
#  'port augusta',
#  'whitehorse',
#  'puerto pinasco',
#  'harper',
#  'bani walid',
#  'saint anthony',
#  'pemberton',
#  'urengoy',
#  'bengkulu',
#  'olinda',
#  'rio grande',
#  'oeiras do para',
#  'iqaluit',
#  'kirkwall',
#  'jambi',
#  'lobva',
#  'san juan',
#  'yate',
#  'ponta delgada',
#  'guaraniacu',
#  'salalah',
#  'biak',
#  'qaanaaq',
#  'torbay',
#  'port lincoln',
#  'havelock',
#  'mattawa',
#  'bathsheba',
#  'korla',
#  'cabra',
#  'huangchuan',
#  'santarem',
#  'ossora',
#  'dekoa',
#  'mentok',
#  'meyungs',
#  'bokoro',
#  'atambua',
#  'arlit',
#  'kununurra',
#  'grand-santi',
#  'los llanos de aridane',
#  'vestmannaeyjar',
#  'samana',
#  'le port',
#  'lalsot',
#  'khandbari',
#  'hemnesberget',
#  'kaoma',
#  'rancho palos verdes',
#  'baracoa',
#  'avila',
#  'teahupoo',
#  'banfora',
#  'gravdal',
#  'kristiinankaupunki',
#  'kapit',
#  'marcona',
#  'nioro',
#  'kyzyl-suu',
#  'erzin',
#  'verkhoyansk',
#  'robertsport',
#  'kalininsk',
#  'ayan',
#  'nakonde',
#  'ambon',
#  'fuxin',
#  'mujiayingzi',
#  'quatre cocos',
#  'santa cruz',
#  'dubbo',
#  'kjollefjord',
#  'bogorodskoye',
#  'kaniama',
#  'jumla',
#  'kamenskoye',
#  'margate',
#  'zhangjiakou',
#  'san carlos de bariloche',
#  'chazuta',
#  'perth',
#  'nouadhibou',
#  'codrington',
#  'bucak',
#  'tezpur',
#  'nanga eboko',
#  'kuytun',
#  'biltine',
#  'pontal do parana',
#  'mrirt',
#  'aasiaat',
#  'ballina',
#  'falealupo',
#  'tabiauea',
#  'brownfield',
#  'anyama',
#  'tautira',
#  'labuan',
#  'kadi',
#  'yushan',
#  'lopez jaena',
#  'morki',
#  'constitucion',
#  'beni',
#  'carora',
#  'kozluk',
#  'tiarei',
#  'mahebourg',
#  'chapulhuacan',
#  'portree',
#  'namtsy',
#  'tadine',
#  'sicuani',
#  'el jicaro',
#  'high level',
#  'ngukurr',
#  'rocha',
#  'basco',
#  'russell',
#  'tessalit',
#  'mporokoso',
#  'myrtle beach',
#  'hami',
#  'ascension',
#  'topolevo',
#  'fort nelson',
#  'veraval',
#  'acarau',
#  'grand river south east',
#  'ambilobe',
#  'muravlenko',
#  'tawnat',
#  'hadrut',
#  'brae',
#  'warmbad',
#  'skibbereen',
#  'port moresby',
#  'kondinskoye',
#  'samusu',
#  'bahia blanca',
#  'sitka',
#  'pietermaritzburg',
#  'sarankhola',
#  'dunedin',
#  'roald',
#  'saint-ambroise',
#  'yenagoa',
#  'feijo',
#  'ye',
#  'jian',
#  'andenes',
#  'oranjemund',
#  'santa rosa',
#  'hovd',
#  'sidi ali',
#  'wahran',
#  'kieta',
#  'zolotinka',
#  'henderson',
#  'loreto',
#  'sorong',
#  'taiyuan',
#  'redondela',
#  'ilave',
#  'marawi',
#  'nanae',
#  'mehamn',
#  'zhangye',
#  'namwala',
#  'shimoda',
#  'parabel',
#  'antofagasta',
#  'ardesen',
#  'hokitika',
#  'resistencia',
#  'srednekolymsk',
#  'naze',
#  'lock haven',
#  'ponta do sol',
#  'qiongshan',
#  'yar-sale',
#  'mopti',
#  'maykopskoye',
#  'shimanovsk',
#  'warqla',
#  'rangoon',
#  'banka',
#  'okhotsk',
#  'ulladulla',
#  'itupiranga',
#  'kidal',
#  'buala',
#  'hermiston',
#  'kourou',
#  'nizhniy kuranakh',
#  'port-gentil',
#  'ovruch',
#  'port hedland',
#  'achisay',
#  'sao felix do xingu',
#  'bereda',
#  'kozloduj',
#  'aksarka',
#  'manaus',
#  'alenquer',
#  'kattivakkam',
#  'tonj',
#  'khani',
#  'nenjiang',
#  'katangli',
#  'belogorsk',
#  'azanka',
#  'yorosso',
#  'yeppoon',
#  'kedrovyy',
#  'nguiu',
#  'marzuq',
#  'half moon bay',
#  'milingimbi',
#  'maniwaki',
#  'urcos',
#  'san jeronimo',
#  'nhulunbuy',
#  'tazovskiy',
#  'celestun',
#  'bad munstereifel',
#  'rincon',
#  'shieli',
#  'hanyang',
#  'college',
#  'luganville',
#  'bekhtery',
#  'kamen-rybolov']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
##
settings = {"units": "Imperial", "appid": api_key}
weather_data = []
lat=[]
lon=[]
temp=[]
cit=[]
temp_max=[]
humidity=[]
wind=[]
date=[]
cloudiness=[]
country=[]

record=1
for city in cities:
    try:  
        weather_data = [ow.get_current(city, **settings)]
        lat.append(weather_data[0]["coord"]["lat"])
        lon.append(weather_data[0]["coord"]["lon"])
        temp.append(weather_data[0]["main"]["temp"])
        cit.append(weather_data[0]["name"])
        humidity.append(weather_data[0]["main"]["humidity"])
        temp_max.append(weather_data[0]["main"]["temp_max"])
        country.append(weather_data[0]["sys"]["country"])
        cloudiness.append(weather_data[0]["clouds"]["all"])
        date.append(weather_data[0]["dt"])
        wind.append(weather_data[0]["wind"]["speed"])
        print(f"Processing Record {record} of Set 1 | {city}")  
        #pprint(weather_data)
        record=record + 1
    except Exception as e:
                print(f"no Data avaiable for city {city},because of {e}")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | longyearbyen
# no Data avaiable for city nizhneyansk,because of HTTP Error 404: Not Found
# Processing Record 4 of Set 1 | luderitz
# no Data avaiable for city olafsvik,because of HTTP Error 404: Not Found
# Processing Record 5 of Set 1 | nelson bay
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | el sauzal
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | karratha
# Processing Record 12 of Set 1 | baiyin
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | sumbe
# Processing Record 15 of Set 1 | northam
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | chapais
# no Data avaiable for city tumannyy,because of HTTP Error 404: Not Found
# Processing Record 19 of Set 1 | te anau
# Processing Record 20 of Set 1 | vao
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | pleasanton
# Processing Record 23 of Set 1 | airai
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | yuksekova
# no Data avaiable for city illoqqortoormiut,because of HTTP Error 404: Not Found
# Processing Record 26 of Set 1 | kavaratti
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | sapucaia
# Processing Record 33 of Set 1 | nanortalik
# no Data avaiable for city taolanaro,because of HTTP Error 404: Not Found
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | opuwo
# Processing Record 36 of Set 1 | coihaique
# Processing Record 37 of Set 1 | bandarbeyla
# Processing Record 38 of Set 1 | deputatskiy
# Processing Record 39 of Set 1 | nanchang
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | townsville
# Processing Record 43 of Set 1 | samarai
# Processing Record 44 of Set 1 | kangaatsiaq
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | fairbanks
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | diamantino
# Processing Record 49 of Set 1 | provideniya
# no Data avaiable for city camana,because of HTTP Error 404: Not Found
# Processing Record 50 of Set 1 | atuona
# Processing Record 51 of Set 1 | tuktoyaktuk
# Processing Record 52 of Set 1 | bannu
# Processing Record 53 of Set 1 | albany
# Processing Record 54 of Set 1 | san antonio
# Processing Record 55 of Set 1 | itirapina
# Processing Record 56 of Set 1 | deniliquin
# Processing Record 57 of Set 1 | itoman
# Processing Record 58 of Set 1 | puerto ayacucho
# Processing Record 59 of Set 1 | ostrovnoy
# Processing Record 60 of Set 1 | cape town
# Processing Record 61 of Set 1 | ryotsu
# Processing Record 62 of Set 1 | griffith
# Processing Record 63 of Set 1 | salinopolis
# Processing Record 64 of Set 1 | imeni poliny osipenko
# Processing Record 65 of Set 1 | fortuna
# Processing Record 66 of Set 1 | puerto ayora
# Processing Record 67 of Set 1 | hualmay
# Processing Record 68 of Set 1 | goderich
# Processing Record 69 of Set 1 | trenggalek
# Processing Record 70 of Set 1 | inuvik
# Processing Record 71 of Set 1 | vila franca do campo
# Processing Record 72 of Set 1 | butaritari
# Processing Record 73 of Set 1 | omboue
# Processing Record 74 of Set 1 | kuna
# Processing Record 75 of Set 1 | birjand
# Processing Record 76 of Set 1 | tigre
# Processing Record 77 of Set 1 | vicente guerrero
# Processing Record 78 of Set 1 | san nicolas
# Processing Record 79 of Set 1 | severo-kurilsk
# Processing Record 80 of Set 1 | ancud
# Processing Record 81 of Set 1 | damietta
# Processing Record 82 of Set 1 | bluff
# Processing Record 83 of Set 1 | yamada
# no Data avaiable for city kachikau,because of HTTP Error 404: Not Found
# Processing Record 84 of Set 1 | lebu
# Processing Record 85 of Set 1 | chuy
# no Data avaiable for city palabuhanratu,because of HTTP Error 404: Not Found
# Processing Record 86 of Set 1 | aklavik
# Processing Record 87 of Set 1 | taoudenni
# Processing Record 88 of Set 1 | hope
# Processing Record 89 of Set 1 | san lorenzo
# Processing Record 90 of Set 1 | pevek
# Processing Record 91 of Set 1 | paamiut
# Processing Record 92 of Set 1 | geraldton
# Processing Record 93 of Set 1 | wuan
# no Data avaiable for city vaitupu,because of HTTP Error 404: Not Found
# Processing Record 94 of Set 1 | kenai
# Processing Record 95 of Set 1 | fukue
# Processing Record 96 of Set 1 | carutapera
# Processing Record 97 of Set 1 | kasongo-lunda
# Processing Record 98 of Set 1 | hervey bay
# Processing Record 99 of Set 1 | tasiilaq
# Processing Record 100 of Set 1 | upernavik
# no Data avaiable for city aflu,because of HTTP Error 404: Not Found
# Processing Record 101 of Set 1 | bredasdorp
# Processing Record 102 of Set 1 | chokurdakh
# Processing Record 103 of Set 1 | severodvinsk
# Processing Record 104 of Set 1 | bambous virieux
# Processing Record 105 of Set 1 | saint george
# Processing Record 106 of Set 1 | nome
# Processing Record 107 of Set 1 | monrovia
# no Data avaiable for city belushya guba,because of HTTP Error 404: Not Found
# Processing Record 108 of Set 1 | bintulu
# Processing Record 109 of Set 1 | clyde river
# Processing Record 110 of Set 1 | cherskiy
# Processing Record 111 of Set 1 | narsaq
# Processing Record 112 of Set 1 | kutum
# Processing Record 113 of Set 1 | verkhniye tatyshly
# Processing Record 114 of Set 1 | mataura
# Processing Record 115 of Set 1 | port alfred
# Processing Record 116 of Set 1 | touros
# Processing Record 117 of Set 1 | mareeba
# Processing Record 118 of Set 1 | sept-iles
# Processing Record 119 of Set 1 | huanren
# Processing Record 120 of Set 1 | tweed
# Processing Record 121 of Set 1 | fomboni
# Processing Record 122 of Set 1 | bay roberts
# Processing Record 123 of Set 1 | lorengau
# Processing Record 124 of Set 1 | wanning
# Processing Record 125 of Set 1 | cordoba
# Processing Record 126 of Set 1 | leisure city
# Processing Record 127 of Set 1 | entre rios
# Processing Record 128 of Set 1 | east london
# no Data avaiable for city krasnoselkup,because of HTTP Error 404: Not Found
# Processing Record 129 of Set 1 | miri
# Processing Record 130 of Set 1 | hithadhoo
# Processing Record 131 of Set 1 | susanville
# Processing Record 132 of Set 1 | agar
# Processing Record 133 of Set 1 | san cristobal
# Processing Record 134 of Set 1 | new norfolk
# no Data avaiable for city sedelnikovo,because of HTTP Error 404: Not Found
# Processing Record 135 of Set 1 | flinders
# Processing Record 136 of Set 1 | kinshasa
# Processing Record 137 of Set 1 | puerto del rosario
# Processing Record 138 of Set 1 | sembakung
# Processing Record 139 of Set 1 | kavieng
# Processing Record 140 of Set 1 | dingle
# Processing Record 141 of Set 1 | onega
# Processing Record 142 of Set 1 | kaeo
# Processing Record 143 of Set 1 | honiara
# Processing Record 144 of Set 1 | mandapam
# Processing Record 145 of Set 1 | katsuura
# Processing Record 146 of Set 1 | launceston
# Processing Record 147 of Set 1 | walvis bay
# Processing Record 148 of Set 1 | vila velha
# Processing Record 149 of Set 1 | lompoc
# Processing Record 150 of Set 1 | faanui
# Processing Record 151 of Set 1 | dikson
# Processing Record 152 of Set 1 | lazaro cardenas
# Processing Record 153 of Set 1 | phan thiet
# Processing Record 154 of Set 1 | pangody
# Processing Record 155 of Set 1 | vardo
# Processing Record 156 of Set 1 | kruisfontein
# Processing Record 157 of Set 1 | tiksi
# Processing Record 158 of Set 1 | saint-philippe
# Processing Record 159 of Set 1 | sudzha
# Processing Record 160 of Set 1 | coquimbo
# Processing Record 161 of Set 1 | norman wells
# Processing Record 162 of Set 1 | dukat
# Processing Record 163 of Set 1 | curuca
# Processing Record 164 of Set 1 | shenzhen
# Processing Record 165 of Set 1 | carnarvon
# Processing Record 166 of Set 1 | guerrero negro
# Processing Record 167 of Set 1 | leningradskiy
# Processing Record 168 of Set 1 | whitecourt
# Processing Record 169 of Set 1 | kijang
# Processing Record 170 of Set 1 | benjamin hill
# Processing Record 171 of Set 1 | urusha
# Processing Record 172 of Set 1 | pisco
# Processing Record 173 of Set 1 | vanavara
# Processing Record 174 of Set 1 | port hardy
# Processing Record 175 of Set 1 | ozark
# Processing Record 176 of Set 1 | ohara
# Processing Record 177 of Set 1 | laguna
# Processing Record 178 of Set 1 | leh
# Processing Record 179 of Set 1 | husavik
# Processing Record 180 of Set 1 | beberibe
# Processing Record 181 of Set 1 | banda aceh
# Processing Record 182 of Set 1 | lakes entrance
# Processing Record 183 of Set 1 | georgetown
# Processing Record 184 of Set 1 | ahipara
# Processing Record 185 of Set 1 | bilibino
# Processing Record 186 of Set 1 | castro
# Processing Record 187 of Set 1 | mar del plata
# Processing Record 188 of Set 1 | ngunguru
# Processing Record 189 of Set 1 | daru
# no Data avaiable for city umzimvubu,because of HTTP Error 404: Not Found
# Processing Record 190 of Set 1 | hasaki
# Processing Record 191 of Set 1 | guna
# Processing Record 192 of Set 1 | turhal
# Processing Record 193 of Set 1 | matam
# no Data avaiable for city sentyabrskiy,because of HTTP Error 404: Not Found
# Processing Record 194 of Set 1 | portland
# Processing Record 195 of Set 1 | port elizabeth
# Processing Record 196 of Set 1 | jiwani
# Processing Record 197 of Set 1 | bloemfontein
# Processing Record 198 of Set 1 | merauke
# Processing Record 199 of Set 1 | acajutla
# Processing Record 200 of Set 1 | salto
# Processing Record 201 of Set 1 | la ronge
# Processing Record 202 of Set 1 | kodiak
# Processing Record 203 of Set 1 | cayenne
# no Data avaiable for city amderma,because of HTTP Error 404: Not Found
# Processing Record 204 of Set 1 | caravelas
# Processing Record 205 of Set 1 | grand gaube
# Processing Record 206 of Set 1 | pangnirtung
# Processing Record 207 of Set 1 | corinto
# Processing Record 208 of Set 1 | kumluca
# Processing Record 209 of Set 1 | sola
# Processing Record 210 of Set 1 | bethel
# Processing Record 211 of Set 1 | sur
# Processing Record 212 of Set 1 | tevaitoa
# no Data avaiable for city berdyuzhye,because of HTTP Error 404: Not Found
# Processing Record 213 of Set 1 | atar
# Processing Record 214 of Set 1 | saldanha
# Processing Record 215 of Set 1 | nabire
# Processing Record 216 of Set 1 | kodinar
# Processing Record 217 of Set 1 | severo-yeniseyskiy
# Processing Record 218 of Set 1 | kahului
# Processing Record 219 of Set 1 | lagunas
# Processing Record 220 of Set 1 | cabo san lucas
# Processing Record 221 of Set 1 | rakitnoye
# Processing Record 222 of Set 1 | nikolskoye
# Processing Record 223 of Set 1 | qiryat yam
# Processing Record 224 of Set 1 | sladkovo
# Processing Record 225 of Set 1 | pindiga
# no Data avaiable for city tongsa,because of HTTP Error 404: Not Found
# Processing Record 226 of Set 1 | grindavik
# Processing Record 227 of Set 1 | komsomolskiy
# Processing Record 228 of Set 1 | mitsamiouli
# Processing Record 229 of Set 1 | istisu
# Processing Record 230 of Set 1 | mananjary
# Processing Record 231 of Set 1 | aktau
# Processing Record 232 of Set 1 | cidreira
# Processing Record 233 of Set 1 | linkoping
# Processing Record 234 of Set 1 | waingapu
# no Data avaiable for city tapaua,because of HTTP Error 404: Not Found
# Processing Record 235 of Set 1 | nouakchott
# Processing Record 236 of Set 1 | toamasina
# Processing Record 237 of Set 1 | kaitangata
# Processing Record 238 of Set 1 | kupang
# Processing Record 239 of Set 1 | owando
# Processing Record 240 of Set 1 | acari
# Processing Record 241 of Set 1 | baker city
# Processing Record 242 of Set 1 | kedougou
# Processing Record 243 of Set 1 | yumen
# Processing Record 244 of Set 1 | stephenville
# Processing Record 245 of Set 1 | taltal
# Processing Record 246 of Set 1 | sinnamary
# Processing Record 247 of Set 1 | sabha
# Processing Record 248 of Set 1 | pilar
# Processing Record 249 of Set 1 | alofi
# Processing Record 250 of Set 1 | san-pedro
# Processing Record 251 of Set 1 | vrangel
# no Data avaiable for city satitoa,because of HTTP Error 404: Not Found
# Processing Record 252 of Set 1 | lavrentiya
# Processing Record 253 of Set 1 | aksay
# Processing Record 254 of Set 1 | sao joao da barra
# Processing Record 255 of Set 1 | polunochnoye
# no Data avaiable for city labutta,because of HTTP Error 404: Not Found
# Processing Record 256 of Set 1 | qaqortoq
# no Data avaiable for city saleaula,because of HTTP Error 404: Not Found
# Processing Record 257 of Set 1 | luga
# Processing Record 258 of Set 1 | lavumisa
# Processing Record 259 of Set 1 | saint-pierre
# Processing Record 260 of Set 1 | victoria
# Processing Record 261 of Set 1 | birao
# Processing Record 262 of Set 1 | isangel
# Processing Record 263 of Set 1 | boden
# Processing Record 264 of Set 1 | san patricio
# Processing Record 265 of Set 1 | hvide sande
# Processing Record 266 of Set 1 | sinegorye
# Processing Record 267 of Set 1 | comodoro rivadavia
# Processing Record 268 of Set 1 | karak
# Processing Record 269 of Set 1 | beringovskiy
# Processing Record 270 of Set 1 | honningsvag
# no Data avaiable for city solovetskiy,because of HTTP Error 404: Not Found
# Processing Record 271 of Set 1 | simbahan
# Processing Record 272 of Set 1 | ust-kut
# Processing Record 273 of Set 1 | ribeira grande
# Processing Record 274 of Set 1 | kuantan
# Processing Record 275 of Set 1 | foumban
# Processing Record 276 of Set 1 | synya
# Processing Record 277 of Set 1 | evensk
# Processing Record 278 of Set 1 | hambantota
# no Data avaiable for city mys shmidta,because of HTTP Error 404: Not Found
# Processing Record 279 of Set 1 | sao filipe
# Processing Record 280 of Set 1 | kokologo
# Processing Record 281 of Set 1 | coswig
# Processing Record 282 of Set 1 | ouesso
# Processing Record 283 of Set 1 | stavern
# Processing Record 284 of Set 1 | podgornoye
# no Data avaiable for city asau,because of HTTP Error 404: Not Found
# Processing Record 285 of Set 1 | meulaboh
# Processing Record 286 of Set 1 | faya
# Processing Record 287 of Set 1 | wenatchee
# Processing Record 288 of Set 1 | gamba
# Processing Record 289 of Set 1 | grande prairie
# Processing Record 290 of Set 1 | alexandria
# Processing Record 291 of Set 1 | sao lourenco do sul
# Processing Record 292 of Set 1 | hun
# Processing Record 293 of Set 1 | broome
# Processing Record 294 of Set 1 | avera
# Processing Record 295 of Set 1 | warrnambool
# Processing Record 296 of Set 1 | willowmore
# Processing Record 297 of Set 1 | tuatapere
# Processing Record 298 of Set 1 | mount gambier
# Processing Record 299 of Set 1 | buchanan
# Processing Record 300 of Set 1 | saskylakh
# no Data avaiable for city skalistyy,because of HTTP Error 404: Not Found
# Processing Record 301 of Set 1 | filingue
# Processing Record 302 of Set 1 | suntar
# Processing Record 303 of Set 1 | saint-georges
# Processing Record 304 of Set 1 | visby
# Processing Record 305 of Set 1 | yerbogachen
# Processing Record 306 of Set 1 | darhan
# Processing Record 307 of Set 1 | solnechnyy
# Processing Record 308 of Set 1 | ivanovka
# Processing Record 309 of Set 1 | rawson
# Processing Record 310 of Set 1 | hay river
# Processing Record 311 of Set 1 | dali
# Processing Record 312 of Set 1 | riyadh
# no Data avaiable for city karaul,because of HTTP Error 404: Not Found
# Processing Record 313 of Set 1 | cairns
# Processing Record 314 of Set 1 | poum
# Processing Record 315 of Set 1 | namibe
# Processing Record 316 of Set 1 | tyrma
# Processing Record 317 of Set 1 | kalamare
# Processing Record 318 of Set 1 | paramonga
# Processing Record 319 of Set 1 | ziyang
# Processing Record 320 of Set 1 | yulara
# Processing Record 321 of Set 1 | kaseda
# Processing Record 322 of Set 1 | tomigusuku
# Processing Record 323 of Set 1 | batemans bay
# Processing Record 324 of Set 1 | mvuma
# Processing Record 325 of Set 1 | mokhsogollokh
# Processing Record 326 of Set 1 | ladario
# Processing Record 327 of Set 1 | devils lake
# Processing Record 328 of Set 1 | moron
# Processing Record 329 of Set 1 | yeniseysk
# no Data avaiable for city barentsburg,because of HTTP Error 404: Not Found
# Processing Record 330 of Set 1 | akureyri
# Processing Record 331 of Set 1 | manglaur
# Processing Record 332 of Set 1 | methven
# no Data avaiable for city attawapiskat,because of HTTP Error 404: Not Found
# Processing Record 333 of Set 1 | mayo
# no Data avaiable for city haibowan,because of HTTP Error 404: Not Found
# Processing Record 334 of Set 1 | huilong
# Processing Record 335 of Set 1 | nuuk
# Processing Record 336 of Set 1 | chandbali
# Processing Record 337 of Set 1 | camacha
# Processing Record 338 of Set 1 | port augusta
# Processing Record 339 of Set 1 | whitehorse
# no Data avaiable for city puerto pinasco,because of HTTP Error 404: Not Found
# Processing Record 340 of Set 1 | harper
# Processing Record 341 of Set 1 | bani walid
# Processing Record 342 of Set 1 | saint anthony
# Processing Record 343 of Set 1 | pemberton
# Processing Record 344 of Set 1 | urengoy
# no Data avaiable for city bengkulu,because of HTTP Error 404: Not Found
# Processing Record 345 of Set 1 | olinda
# Processing Record 346 of Set 1 | rio grande
# Processing Record 347 of Set 1 | oeiras do para
# Processing Record 348 of Set 1 | iqaluit
# Processing Record 349 of Set 1 | kirkwall
# Processing Record 350 of Set 1 | jambi
# Processing Record 351 of Set 1 | lobva
# Processing Record 352 of Set 1 | san juan
# Processing Record 353 of Set 1 | yate
# Processing Record 354 of Set 1 | ponta delgada
# Processing Record 355 of Set 1 | guaraniacu
# Processing Record 356 of Set 1 | salalah
# Processing Record 357 of Set 1 | biak
# Processing Record 358 of Set 1 | qaanaaq
# Processing Record 359 of Set 1 | torbay
# Processing Record 360 of Set 1 | port lincoln
# Processing Record 361 of Set 1 | havelock
# Processing Record 362 of Set 1 | mattawa
# Processing Record 363 of Set 1 | bathsheba
# no Data avaiable for city korla,because of HTTP Error 404: Not Found
# Processing Record 364 of Set 1 | cabra
# Processing Record 365 of Set 1 | huangchuan
# no Data avaiable for city santarem,because of HTTP Error 404: Not Found
# Processing Record 366 of Set 1 | ossora
# no Data avaiable for city dekoa,because of HTTP Error 404: Not Found
# no Data avaiable for city mentok,because of HTTP Error 404: Not Found
# no Data avaiable for city meyungs,because of HTTP Error 404: Not Found
# no Data avaiable for city bokoro,because of HTTP Error 404: Not Found
# Processing Record 367 of Set 1 | atambua
# Processing Record 368 of Set 1 | arlit
# Processing Record 369 of Set 1 | kununurra
# Processing Record 370 of Set 1 | grand-santi
# Processing Record 371 of Set 1 | los llanos de aridane
# Processing Record 372 of Set 1 | vestmannaeyjar
# Processing Record 373 of Set 1 | samana
# Processing Record 374 of Set 1 | le port
# Processing Record 375 of Set 1 | lalsot
# Processing Record 376 of Set 1 | khandbari
# Processing Record 377 of Set 1 | hemnesberget
# Processing Record 378 of Set 1 | kaoma
# Processing Record 379 of Set 1 | rancho palos verdes
# Processing Record 380 of Set 1 | baracoa
# Processing Record 381 of Set 1 | avila
# Processing Record 382 of Set 1 | teahupoo
# Processing Record 383 of Set 1 | banfora
# Processing Record 384 of Set 1 | gravdal
# no Data avaiable for city kristiinankaupunki,because of HTTP Error 404: Not Found
# Processing Record 385 of Set 1 | kapit
# no Data avaiable for city marcona,because of HTTP Error 404: Not Found
# Processing Record 386 of Set 1 | nioro
# Processing Record 387 of Set 1 | kyzyl-suu
# Processing Record 388 of Set 1 | erzin
# Processing Record 389 of Set 1 | verkhoyansk
# Processing Record 390 of Set 1 | robertsport
# Processing Record 391 of Set 1 | kalininsk
# Processing Record 392 of Set 1 | ayan
# Processing Record 393 of Set 1 | nakonde
# Processing Record 394 of Set 1 | ambon
# Processing Record 395 of Set 1 | fuxin
# Processing Record 396 of Set 1 | mujiayingzi
# Processing Record 397 of Set 1 | quatre cocos
# Processing Record 398 of Set 1 | santa cruz
# Processing Record 399 of Set 1 | dubbo
# Processing Record 400 of Set 1 | kjollefjord
# Processing Record 401 of Set 1 | bogorodskoye
# Processing Record 402 of Set 1 | kaniama
# Processing Record 403 of Set 1 | jumla
# no Data avaiable for city kamenskoye,because of HTTP Error 404: Not Found
# Processing Record 404 of Set 1 | margate
# Processing Record 405 of Set 1 | zhangjiakou
# Processing Record 406 of Set 1 | san carlos de bariloche
# Processing Record 407 of Set 1 | chazuta
# Processing Record 408 of Set 1 | perth
# Processing Record 409 of Set 1 | nouadhibou
# Processing Record 410 of Set 1 | codrington
# Processing Record 411 of Set 1 | bucak
# Processing Record 412 of Set 1 | tezpur
# Processing Record 413 of Set 1 | nanga eboko
# Processing Record 414 of Set 1 | kuytun
# Processing Record 415 of Set 1 | biltine
# Processing Record 416 of Set 1 | pontal do parana
# no Data avaiable for city mrirt,because of HTTP Error 404: Not Found
# Processing Record 417 of Set 1 | aasiaat
# Processing Record 418 of Set 1 | ballina
# no Data avaiable for city falealupo,because of HTTP Error 404: Not Found
# no Data avaiable for city tabiauea,because of HTTP Error 404: Not Found
# Processing Record 419 of Set 1 | brownfield
# Processing Record 420 of Set 1 | anyama
# Processing Record 421 of Set 1 | tautira
# Processing Record 422 of Set 1 | labuan
# Processing Record 423 of Set 1 | kadi
# Processing Record 424 of Set 1 | yushan
# Processing Record 425 of Set 1 | lopez jaena
# Processing Record 426 of Set 1 | morki
# Processing Record 427 of Set 1 | constitucion
# Processing Record 428 of Set 1 | beni
# Processing Record 429 of Set 1 | carora
# Processing Record 430 of Set 1 | kozluk
# Processing Record 431 of Set 1 | tiarei
# Processing Record 432 of Set 1 | mahebourg
# Processing Record 433 of Set 1 | chapulhuacan
# Processing Record 434 of Set 1 | portree
# Processing Record 435 of Set 1 | namtsy
# Processing Record 436 of Set 1 | tadine
# Processing Record 437 of Set 1 | sicuani
# Processing Record 438 of Set 1 | el jicaro
# Processing Record 439 of Set 1 | high level
# no Data avaiable for city ngukurr,because of HTTP Error 404: Not Found
# Processing Record 440 of Set 1 | rocha
# Processing Record 441 of Set 1 | basco
# Processing Record 442 of Set 1 | russell
# Processing Record 443 of Set 1 | tessalit
# Processing Record 444 of Set 1 | mporokoso
# Processing Record 445 of Set 1 | myrtle beach
# Processing Record 446 of Set 1 | hami
# no Data avaiable for city ascension,because of HTTP Error 404: Not Found
# Processing Record 447 of Set 1 | topolevo
# Processing Record 448 of Set 1 | fort nelson
# Processing Record 449 of Set 1 | veraval
# no Data avaiable for city acarau,because of HTTP Error 404: Not Found
# no Data avaiable for city grand river south east,because of HTTP Error 404: Not Found
# Processing Record 450 of Set 1 | ambilobe
# Processing Record 451 of Set 1 | muravlenko
# no Data avaiable for city tawnat,because of HTTP Error 404: Not Found
# Processing Record 452 of Set 1 | hadrut
# Processing Record 453 of Set 1 | brae
# Processing Record 454 of Set 1 | warmbad
# Processing Record 455 of Set 1 | skibbereen
# Processing Record 456 of Set 1 | port moresby
# Processing Record 457 of Set 1 | kondinskoye
# no Data avaiable for city samusu,because of HTTP Error 404: Not Found
# Processing Record 458 of Set 1 | bahia blanca
# Processing Record 459 of Set 1 | sitka
# Processing Record 460 of Set 1 | pietermaritzburg
# Processing Record 461 of Set 1 | sarankhola
# Processing Record 462 of Set 1 | dunedin
# Processing Record 463 of Set 1 | roald
# Processing Record 464 of Set 1 | saint-ambroise
# Processing Record 465 of Set 1 | yenagoa
# Processing Record 466 of Set 1 | feijo
# no Data avaiable for city ye,because of HTTP Error 404: Not Found
# Processing Record 467 of Set 1 | jian
# no Data avaiable for city andenes,because of HTTP Error 404: Not Found
# Processing Record 468 of Set 1 | oranjemund
# Processing Record 469 of Set 1 | santa rosa
# Processing Record 470 of Set 1 | hovd
# Processing Record 471 of Set 1 | sidi ali
# no Data avaiable for city wahran,because of HTTP Error 404: Not Found
# Processing Record 472 of Set 1 | kieta
# no Data avaiable for city zolotinka,because of HTTP Error 404: Not Found
# Processing Record 473 of Set 1 | henderson
# Processing Record 474 of Set 1 | loreto
# Processing Record 475 of Set 1 | sorong
# Processing Record 476 of Set 1 | taiyuan
# Processing Record 477 of Set 1 | redondela
# Processing Record 478 of Set 1 | ilave
# Processing Record 479 of Set 1 | marawi
# Processing Record 480 of Set 1 | nanae
# Processing Record 481 of Set 1 | mehamn
# Processing Record 482 of Set 1 | zhangye
# Processing Record 483 of Set 1 | namwala
# Processing Record 484 of Set 1 | shimoda
# Processing Record 485 of Set 1 | parabel
# Processing Record 486 of Set 1 | antofagasta
# Processing Record 487 of Set 1 | ardesen
# Processing Record 488 of Set 1 | hokitika
# Processing Record 489 of Set 1 | resistencia
# Processing Record 490 of Set 1 | srednekolymsk
# Processing Record 491 of Set 1 | naze
# Processing Record 492 of Set 1 | lock haven
# Processing Record 493 of Set 1 | ponta do sol
# Processing Record 494 of Set 1 | qiongshan
# Processing Record 495 of Set 1 | yar-sale
# Processing Record 496 of Set 1 | mopti
# Processing Record 497 of Set 1 | maykopskoye
# Processing Record 498 of Set 1 | shimanovsk
# no Data avaiable for city warqla,because of HTTP Error 404: Not Found
# Processing Record 499 of Set 1 | rangoon
# Processing Record 500 of Set 1 | banka
# Processing Record 501 of Set 1 | okhotsk
# Processing Record 502 of Set 1 | ulladulla
# Processing Record 503 of Set 1 | itupiranga
# Processing Record 504 of Set 1 | kidal
# Processing Record 505 of Set 1 | buala
# Processing Record 506 of Set 1 | hermiston
# Processing Record 507 of Set 1 | kourou
# Processing Record 508 of Set 1 | nizhniy kuranakh
# Processing Record 509 of Set 1 | port-gentil
# Processing Record 510 of Set 1 | ovruch
# Processing Record 511 of Set 1 | port hedland
# no Data avaiable for city achisay,because of HTTP Error 404: Not Found
# Processing Record 512 of Set 1 | sao felix do xingu
# Processing Record 513 of Set 1 | bereda
# no Data avaiable for city kozloduj,because of HTTP Error 404: Not Found
# Processing Record 514 of Set 1 | aksarka
# Processing Record 515 of Set 1 | manaus
# Processing Record 516 of Set 1 | alenquer
# Processing Record 517 of Set 1 | kattivakkam
# no Data avaiable for city tonj,because of HTTP Error 404: Not Found
# Processing Record 518 of Set 1 | khani
# Processing Record 519 of Set 1 | nenjiang
# Processing Record 520 of Set 1 | katangli
# Processing Record 521 of Set 1 | belogorsk
# Processing Record 522 of Set 1 | azanka
# Processing Record 523 of Set 1 | yorosso
# Processing Record 524 of Set 1 | yeppoon
# Processing Record 525 of Set 1 | kedrovyy
# no Data avaiable for city nguiu,because of HTTP Error 404: Not Found
# Processing Record 526 of Set 1 | marzuq
# Processing Record 527 of Set 1 | half moon bay
# no Data avaiable for city milingimbi,because of HTTP Error 404: Not Found
# Processing Record 528 of Set 1 | maniwaki
# Processing Record 529 of Set 1 | urcos
# Processing Record 530 of Set 1 | san jeronimo
# Processing Record 531 of Set 1 | nhulunbuy
# Processing Record 532 of Set 1 | tazovskiy
# Processing Record 533 of Set 1 | celestun
# Processing Record 534 of Set 1 | bad munstereifel
# Processing Record 535 of Set 1 | rincon
# Processing Record 536 of Set 1 | shieli
# Processing Record 537 of Set 1 | hanyang
# Processing Record 538 of Set 1 | college
# Processing Record 539 of Set 1 | luganville
# Processing Record 540 of Set 1 | bekhtery
# Processing Record 541 of Set 1 | kamen-rybolov

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city": cit,
    "Cloudiness": cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lon,
    "Max Temp":temp_max,
    "Wind Speed": wind,
    
    
}
weather_data = pd.DataFrame(weather_dict)

weather_data.head()

weather_data.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
date_ms=weather_data.iloc[0,3]

date_ms=datetime.utcfromtimestamp(date_ms).strftime('%m-%d-%y')

plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temprature({date_ms})")
plt.ylabel("Max Temprature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity({date_ms}) ")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({date_ms})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({date_ms})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
